# %%
% Design complete pipeline with cpu threading (chunking), use classical method of parsing

# %%
# !pip install pymupdf
# !python.exe -m pip install --upgrade pip
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pymupdf in c:\users\kasif\appdata\roaming\python\python313\site-packages (1.26.7)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pip in c:\users\kasif\appdata\roaming\python\python313\site-packages (25.3)

# %%
import fitz  # pip install pymupdf

pdf_path = "Macromolecular Rapid Communications - 2018 - Yao - Recent Development of Thermoelectric Polymers and Composites.pdf"
doc = fitz.open(pdf_path)

for page_index in range(len(doc)):
    page = doc[page_index]

    images = page.get_images(full=True)  # list of embedded images
    drawings = page.get_drawings()       # vector paths (lines/curves)
    text = page.get_text("text").strip() # extracted text

    print(f"\nPage {page_index+1}")
    print(f"  Embedded images: {len(images)}")
    print(f"  Vector drawing objects: {len(drawings)}")
    print(f"  Has text: {bool(text)}")

    # If you want details about each raster image:
    for img in images[:5]:
        xref = img[0]
        info = doc.extract_image(xref)
        print(f"    - image xref={xref}, format={info.get('ext')}, size={info.get('width')}x{info.get('height')}")
# Out:
# Page 1
#   Embedded images: 1
#   Vector drawing objects: 350
#   Has text: True
#     - image xref=106, format=png, size=406x424
#
# Page 2
#   Embedded images: 3
#   Vector drawing objects: 390
#   Has text: True
#     - image xref=81, format=jpeg, size=551x709
#     - image xref=82, format=jpeg, size=551x709
#     - image xref=106, format=png, size=406x424
#
# Page 3
#   Embedded images: 2
#   Vector drawing objects: 384
#   Has text: True
#     - image xref=111, format=png, size=2333x2356
#     - image xref=106, format=png, size=406x424
#
# Page 4
#   Embedded images: 2
#   Vector drawing objects: 363
#   Has text: True
#     - image xref=124, format=jpeg, size=1327x1783
#     - image xref=106, format=png, size=406x424
#
# Page 5
#   Embedded images: 3
#   Vector drawing objects: 363
#   Has text: True
#     - image xref=134, format=jpeg, size=2000x1013
#     - image xref=135, format=png, size=2333x1983
#     - image xref=106, format=png, size=406x424
#
# Page 6
#   Embedded images: 2
#   Vector drawing objects: 387
#   Has text: True
#     - image xref=144, format=jpeg, size=1300x1025
#     - image xref=106, format=png, size=406x424
#
# Page 7
#   Embedded images: 1
#   Vector drawing objects: 384
#   Has text: True
#     - image xref=106, format=png, size=406x424
#
# Page 8
#   Embedded images: 2
#   Vector drawing objects: 363
#   Has text: True
#     - image xref=154, format=jpeg, size=2660x861
#     - image xref=106, format=png, size=406x424
#
# Page 9
#   Embedded images: 1
#   Vector drawing objects: 387
#   Has text: True
#     - image xref=106, format=png, size=406x424
#
# Page 10
#   Embedded images: 1
#   Vector drawing objects: 387
#   Has text: True
#     - image xref=106, format=png, size=406x424
#
# Page 11
#   Embedded images: 2
#   Vector drawing objects: 363
#   Has text: True
#     - image xref=167, format=png, size=2660x1293
#     - image xref=106, format=png, size=406x424
#
# Page 12
#   Embedded images: 2
#   Vector drawing objects: 393
#   Has text: True
#     - image xref=178, format=jpeg, size=2333x881
#     - image xref=106, format=png, size=406x424
#
# Page 13
#   Embedded images: 2
#   Vector drawing objects: 363
#   Has text: True
#     - image xref=196, format=jpeg, size=2660x1199
#     - image xref=106, format=png, size=406x424
#
# Page 14
#   Embedded images: 2
#   Vector drawing objects: 363
#   Has text: True
#     - image xref=207, format=jpeg, size=2010x947
#     - image xref=106, format=png, size=406x424
#
# Page 15
#   Embedded images: 2
#   Vector drawing objects: 393
#   Has text: True
#     - image xref=213, format=jpeg, size=1267x733
#     - image xref=106, format=png, size=406x424
#
# Page 16
#   Embedded images: 3
#   Vector drawing objects: 363
#   Has text: True
#     - image xref=219, format=jpeg, size=2333x604
#     - image xref=220, format=jpeg, size=1733x754
#     - image xref=106, format=png, size=406x424
#
# Page 17
#   Embedded images: 2
#   Vector drawing objects: 390
#   Has text: True
#     - image xref=229, format=jpeg, size=2660x2272
#     - image xref=106, format=png, size=406x424
#
# Page 18
#   Embedded images: 2
#   Vector drawing objects: 393
#   Has text: True
#     - image xref=235, format=jpeg, size=2000x1698
#     - image xref=106, format=png, size=406x424
#
# Page 19
#   Embedded images: 1
#   Vector drawing objects: 364
#   Has text: True
#     - image xref=106, format=png, size=406x424
#
# Page 20
#   Embedded images: 1
#   Vector drawing objects: 363
#   Has text: True
#     - image xref=106, format=png, size=406x424
#
# Page 21
#   Embedded images: 1
#   Vector drawing objects: 363
#   Has text: True
#     - image xref=106, format=png, size=406x424
#
# Page 22
#   Embedded images: 1
#   Vector drawing objects: 363
#   Has text: True
#     - image xref=106, format=png, size=406x424
