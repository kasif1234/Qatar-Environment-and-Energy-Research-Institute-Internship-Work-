# %%
#=================================================================================================
# Libraries:
# 1. pandas — to load, clean, and organize the CSV data into tables you can analyze easily.
# 2. matplotlib — to create the bar chart, box plots, and histogram plots.
# 3. scipy — to calculate the Pearson correlation and other statistical values.
# 4. numpy — to handle numerical operations efficiently behind the scenes.
# 5. seaborn — to make the plots look cleaner and more polished with less code.
#=================================================================================================
# Types of Plots:
# 1. Bar Chart: To compare the average values of a specific column across different categories.
# 2. Box Plot: To visualize the distribution of a numerical column and identify outliers
# 3. Histogram: To show the frequency distribution of a numerical column and understand its shape.
# 4. Pearson Correlation: To measure the strength and direction of the linear relationship between two numerical columns.
#=================================================================================================
# Graphs we can make now - Transcribed from 08/04/2026 Meeting:
# Histogram - Count on y axis and {Variable} on x axis - At least 5 Figures

# https://chatgpt.com/c/69dd0506-45f4-8392-9f9b-efca2313721a

# %%
import pandas as pd

file_path = "Complete Extraction Results.xlsx"

# Open the Excel file
excel_file = pd.ExcelFile(file_path, engine="openpyxl")

# Show all sheet names
print("Available sheets:")
for i, sheet in enumerate(excel_file.sheet_names, start=1):
    print(f"{i}. {sheet}")

# Select a sheet by number
choice = int(input("Enter sheet number: "))
selected_sheet = excel_file.sheet_names[choice - 1]

# Read that sheet
df = pd.read_excel(file_path, sheet_name=selected_sheet, engine="openpyxl", header=1)

print(f"\nLoaded sheet: {selected_sheet}")
print(df.head())
print(f"\nColumns in the sheet: {df.columns.tolist()[0:10]}")  # Show first 10 columns for brevity

# Make dictionary: key -> column name
column_dict = {i: col for i, col in enumerate(df.columns, start=1)}

print("\nColumn dictionary:")
for k, v in column_dict.items():
    print(f"{k}: {v}")
# Out:
# Available sheets:
# 1. Structure
# 2. Graphs (6 Types)
# 3. ReadMe
# 4. Extra
# Enter sheet number:  2
# Loaded sheet: Graphs (6 Types)
#    datapoint_id  id exact_polymer_name                         Polymer Family  \
# 0           NaN  A1          PDPPSe-12  Diketopyrrolopyrrole (DPP) derivative
# 1           NaN  A1          PDPPSe-12  Diketopyrrolopyrrole (DPP) derivative
# 2           NaN  A1          PDPPSe-12  Diketopyrrolopyrrole (DPP) derivative
# 3           NaN  A1          PDPPSe-12  Diketopyrrolopyrrole (DPP) derivative
# 4           NaN  A1          PDPPSe-12  Diketopyrrolopyrrole (DPP) derivative
#
#    Chemical Structure (Image) Repeating Unit Formula  \
# 0                         NaN         C53H78N2O2S2Se
# 1                         NaN         C53H78N2O2S2Se
# 2                         NaN         C53H78N2O2S2Se
# 3                         NaN         C53H78N2O2S2Se
# 4                         NaN         C53H78N2O2S2Se
#
#    Molecular Weight of the Repeating Unit (g/mol)  \
# 0                                          918.31
# 1                                          918.31
# 2                                          918.31
# 3                                          918.31
# 4                                          918.31
#
#    Molecular Weight - (polymer molecular weight/repeat-unit molecular weight) (Number of repeated monomers)  \
# 0                                          48.785269
# 1                                          48.785269
# 2                                          48.785269
# 3                                          48.785269
# 4                                          48.785269
#
#   Film Method Preparation  Mw (Weight Average Molecular Weight) [kDa]   ...  \
# 0            Spin-coating                                         44.8  ...
# 1            Spin-coating                                         44.8  ...
# 2            Spin-coating                                         44.8  ...
# 3            Spin-coating                                         44.8  ...
# 4            Spin-coating                                         44.8  ...
#
#    ZT_Calculated  units_doping_level graph_type digitization_method Notes  \
# 0            NaN                 NaN        NaN                 NaN   NaN
# 1            NaN                 NaN        NaN                 NaN   NaN
# 2            NaN                 NaN        NaN                 NaN   NaN
# 3            NaN                 NaN        NaN                 NaN   NaN
# 4            NaN                 NaN        NaN                 NaN   NaN
#
#                         Key Insights from this paper  \
# 0  Key Insights from the Sources:\nVariable Integ...
# 1                                      Same as Above
# 2                                      Same as Above
# 3                                      Same as Above
# 4                                      Same as Above
#
#   Number of Additional Papers Covered  \
# 0                                 1.0
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
#
#   Number of Additional Papers Covered - Extra Information  \
# 0  Selenium-substituted diketopyrrolopyrrole poly...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                 reference_doi      evidence_location
# 0  https://doi.org/10.1038/s41586-024-07724-2  Methods, Fig 1, Fig 3
# 1  https://doi.org/10.1038/s41586-024-07724-2  Methods, Fig 1, Fig 3
# 2  https://doi.org/10.1038/s41586-024-07724-2  Methods, Fig 1, Fig 3
# 3  https://doi.org/10.1038/s41586-024-07724-2  Methods, Fig 1, Fig 3
# 4  https://doi.org/10.1038/s41586-024-07724-2  Methods, Fig 1, Fig 3
#
# [5 rows x 65 columns]
#
# Columns in the sheet: ['datapoint_id', 'id', 'exact_polymer_name', 'Polymer Family', 'Chemical Structure (Image)', 'Repeating Unit Formula', 'Molecular Weight of the Repeating Unit (g/mol)', 'Molecular Weight - (polymer molecular weight/repeat-unit molecular weight) (Number of repeated monomers)', 'Film Method Preparation', 'Mw (Weight Average Molecular Weight) [kDa] ']
#
# Column dictionary:
# 1: datapoint_id
# 2: id
# 3: exact_polymer_name
# 4: Polymer Family
# 5: Chemical Structure (Image)
# 6: Repeating Unit Formula
# 7: Molecular Weight of the Repeating Unit (g/mol)
# 8: Molecular Weight - (polymer molecular weight/repeat-unit molecular weight) (Number of repeated monomers)
# 9: Film Method Preparation
# 10: Mw (Weight Average Molecular Weight) [kDa]
# 11: PDI (Polydispersity Index)
# 12: Mn (Number Average Molecular Weight)  [kDa]
# 13: Dopant
# 14: Doping Level (Solution Concentration)
# 15: carrier_type
# 16: dopant_solvent
# 17: Polymer_Solvent
# 18: doping_method
# 19: annealing_temperature
# 20: annealing condition
# 21: annealing_time
# 22: annealing_atmosphere
# 23: film_thickness_nm
# 24: substrate_type
# 25: measurement_atmosphere
# 26: measurement_temperature_K
# 27: orientation_or_alignment
# 28: sample_form
# 29: thermal_conductivity
# 30: thermal_conductivity_method
# 31: doping_time
# 32: post_treatment
# 33: SMILES/InChI
# 34: Unnamed: 33
# 35: Unnamed: 34
# 36: graph_variable [Y vs X] [Type 1]
# 37: seebeck_coefficient
# 38: doping_or_oxidation_level
# 39: graph_variable [Y vs X] [Type 2]
# 40: electrical_conductivity
# 41: doping_or_oxidation_level.1
# 42: graph_variable [Y vs X] [Type 3]
# 43: power_factor_Extracted
# 44: doping_or_oxidation_level.2
# 45: graph_variable [Y vs X] [Type 4]
# 46: ZT
# 47: Temperature
# 48: graph_variable [Y vs X] [Type 5]
# 49: seebeck_coefficient.1
# 50: electrical_conductivity.1
# 51: graph_variable [Y vs X] [Type 6]
# 52: power_factor_Extracted.1
# 53: electrical_conductivity.2
# 54: Doping Temperature Celcius
# 55: power_factor_Calculated
# 56: ZT_Calculated
# 57: units_doping_level
# 58: graph_type
# 59: digitization_method
# 60: Notes
# 61: Key Insights from this paper
# 62: Number of Additional Papers Covered
# 63: Number of Additional Papers Covered - Extra Information
# 64: reference_doi
# 65: evidence_location

# %% [markdown]
# # Figures: Count Vs {Variable}

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

col_name = column_dict[49]
x = pd.to_numeric(df[col_name], errors='coerce')
x = x.replace([np.inf, -np.inf], np.nan).dropna()
x = x[x > 0]

# Log-spaced bins
bins = np.logspace(np.log10(x.min()), np.log10(x.max()), 40)

# Histogram counts
counts, bin_edges = np.histogram(x, bins=bins)

# Bin centers
bin_centers = np.sqrt(bin_edges[:-1] * bin_edges[1:])   # better for log scale

plt.figure(figsize=(7, 5))

# Histogram
plt.hist(x, bins=bins, color='skyblue', edgecolor='black', linewidth=0.5)

# Line connecting bar tips
plt.plot(bin_centers, counts, linewidth=1.5)
plt.grid()

plt.xscale('log')
plt.xlabel("Seebeck (S/cm)")
plt.ylabel('Count')
plt.title("Histogram")

plt.tight_layout()
plt.show()
# Out:
#   Cell In[13], line 26
#     plt.grid(
#             ^
# SyntaxError: '(' was never closed
